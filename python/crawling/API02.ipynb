# %%
# 마포구 유동인구 데이터

import requests
import json
import pandas as pd

url = 'http://apis.data.go.kr/3130000/openapi/floatingPopulation/getfloatingPopulation?serviceKey=o0CmhlAvqpjrYb4A%2BYeoTcpt5T9kN0rHF7L1Tcrw8Th1mDZaspp%2Bj0JaW9edrluemEotB58VFRjSoJKAqb88dQ%3D%3D&filterKey=addr &numOfRows=200&pageNo=0&type=json'
response = requests.get(url)

print(response.content)
# Out:
# b'{"resultCode":"0","resultMsg":"SUCCESS","numOfRows":200,"pageNo":0,"totalCount":289,"items":[{"grid_id":"1712","_left":"302127.0002","top":"553818.0001","_right":"302227.0002","bottom":"553718.0001","_14age":"5.031010929","_20_50T21_":"44.27010712","_65age_":"22.42185792","_20_60T9_18":"3967.117824","weekend":"896.6073076","addr":"\xeb\x94\x94\xec\xa7\x80\xed\x84\xb8\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4\xec\x8b\x9c\xed\x8b\xb0\xec\x9d\xb8\xea\xb7\xbc\xec\xa3\xbc\xea\xb1\xb0\xeb\xb0\x80\xec\xa7\x91\xec\xa7\x80\xec\x97\xad"},{"grid_id":"1713","_left":"302127.0002","top":"553718.0001","_right":"302227.0002","bottom":"553618.0001","_14age":"4.037377049","_20_50T21_":"7.54068306","_65age_":"24.81259563","_20_60T9_18":"3654.89145","weekend":"792.9247115","addr":"\xeb\x94\x94\xec\xa7\x80\xed\x84\xb8\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4\xec\x8b\x9c\xed\x8b\xb0\xec\x9d\xb8\xea\xb7\xbc\xec\xa3\xbc\xea\xb1\xb0\xeb\xb0\x80\xec\xa7\x91\xec\xa7\x80\xec\x97\xad"},{"grid_id":"1714","_left":"302127.0
# ...

# %%
json_df = response.json()
# print(json_df)
df_mapo = pd.DataFrame(json_df['items'])
df_mapo = df_mapo.loc[:, '_14age':]
df_mapo
# Out:
#           _14age   _20_50T21_      _65age_  _20_60T9_18      weekend  \
# 0    5.031010929  44.27010712  22.42185792  3967.117824  896.6073076
# 1    4.037377049   7.54068306  24.81259563   3654.89145  792.9247115
# 2    7.151147541  60.77628416  74.66407104  9800.108435  1395.093558
# 3    4.352622951  63.87762296  36.21480874  1125.146756  824.7529808
# 4    1.884836064  82.04745902  33.26150273  1775.627939  944.9479808
# ..           ...          ...          ...          ...          ...
# 195  6.946120218  126.6107377  106.7879508  1150.231069  1847.675192
# 196  10.14333333  179.0786066  132.0506831  2164.501756  2958.998653
# 197  16.68513661   281.710847  219.2652732  4694.817901  5299.669422
# 198  29.63765027  294.0084699  149.7540164  4042.023779  6108.621731
# 199  80.79879781  158.1533613  284.3945902  1330.784809  2646.266539
#
#                  addr
# 0    디지털미디어시티인근주거밀집지역
# 1    디지털미디어시티인근주거밀집지역
# 2    디지털미디어시티인근주거밀집지역
# 3    디지털미디어시티인근주거밀집지역
# ...

# %%
# 도시 데이터 센서 유동인구 측정

import requests
import json
import pandas as pd

url = 'http://openapi.seoul.go.kr:8088/774362517673706136304c45676448/json/IotVdata018/1/50/'
response = requests.get(url)

print(response.content)
# Out:
# b'{"IotVdata018":{"list_total_count":1941028,"RESULT":{"CODE":"INFO-000","MESSAGE":"\xec\xa0\x95\xec\x83\x81 \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4"},"row":[{"MODEL_NM":"SDOT001","SERIAL_NO":"00000003036","SENSING_TIME":"2023-08-08_23:48:00","REGION":"traditional_markets","AUTONOMOUS_DISTRICT":"Dongjak-gu","ADMINISTRATIVE_DISTRICT":"Sang-do4-dong","VISITOR_COUNT":"209","REG_DTTM":"2023-08-08 23:58:05"},{"MODEL_NM":"SDOT001","SERIAL_NO":"00000004046","SENSING_TIME":"2023-08-08_23:40:00","REGION":"main_street","AUTONOMOUS_DISTRICT":"Gangnam-gu","ADMINISTRATIVE_DISTRICT":"Sinsa-dong","VISITOR_COUNT":"10","REG_DTTM":"2023-08-08 23:58:05"},{"MODEL_NM":"SDOT001","SERIAL_NO":"00000003033","SENSING_TIME":"2023-08-08_23:48:00","REGION":"traditional_markets","AUTONOMOUS_DISTRICT":"Dongjak-gu","ADMINISTRATIVE_DISTRICT":"Sadang2-dong","VISITOR_COUNT":"183","REG_DTTM":"2023-08-08 23:58:05"},{"MODEL_NM":"SDOT001","SERIAL_NO":"00000004010","SENSING_TIME
# ...

# %%
json = response.json()
print(json)
df = pd.DataFrame(json['IotVdata018']['row'])
df
# Out:
# {'IotVdata018': {'list_total_count': 1941028, 'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'}, 'row': [{'MODEL_NM': 'SDOT001', 'SERIAL_NO': '00000003036', 'SENSING_TIME': '2023-08-08_23:48:00', 'REGION': 'traditional_markets', 'AUTONOMOUS_DISTRICT': 'Dongjak-gu', 'ADMINISTRATIVE_DISTRICT': 'Sang-do4-dong', 'VISITOR_COUNT': '209', 'REG_DTTM': '2023-08-08 23:58:05'}, {'MODEL_NM': 'SDOT001', 'SERIAL_NO': '00000004046', 'SENSING_TIME': '2023-08-08_23:40:00', 'REGION': 'main_street', 'AUTONOMOUS_DISTRICT': 'Gangnam-gu', 'ADMINISTRATIVE_DISTRICT': 'Sinsa-dong', 'VISITOR_COUNT': '10', 'REG_DTTM': '2023-08-08 23:58:05'}, {'MODEL_NM': 'SDOT001', 'SERIAL_NO': '00000003033', 'SENSING_TIME': '2023-08-08_23:48:00', 'REGION': 'traditional_markets', 'AUTONOMOUS_DISTRICT': 'Dongjak-gu', 'ADMINISTRATIVE_DISTRICT': 'Sadang2-dong', 'VISITOR_COUNT': '183', 'REG_DTTM': '2023-08-08 23:58:05'}, {'MODEL_NM': 'SDOT001', 'SERIAL_NO': '00000004010', 'SENSING_TIME': '2023-08-08_23:45:00', 'REGION': 'mai
# ...

# %%
df.sort_values(by='VISITOR_COUNT')
# Out:
#    MODEL_NM    SERIAL_NO         SENSING_TIME               REGION  \
# 21  SDOT001  00000004045  2023-08-08_23:42:00                parks
# 19  SDOT001  00000004006  2023-08-08_23:40:00                parks
# 29  SDOT001  00000004034  2023-08-08_23:45:00                parks
# 10  SDOT001  00000004050  2023-08-08_23:46:00    public_facilities
# 34  SDOT001  00000004043  2023-08-08_23:40:00                parks
# 49  SDOT001  00000004024  2023-08-08_23:45:00  traditional_markets
# 1   SDOT001  00000004046  2023-08-08_23:40:00          main_street
# 33  SDOT001  00000003017  2023-08-08_23:48:00  traditional_markets
# 40  SDOT001  00000003034  2023-08-08_23:48:00  traditional_markets
# 39  SDOT001  00000004007  2023-08-08_23:47:00          main_street
# 15  SDOT001  00000004009  2023-08-08_23:46:00          main_street
# 13  SDOT001  00000002994  2023-08-08_23:48:00  traditional_markets
# 43  SDOT001  00000003024  2023-08-08_23:48:00  traditional_markets
# ...

# %%
# 한국관광공사_관광빅데이터 정보서비스

url = 'http://apis.data.go.kr/B551011/DataLabService/metcoRegnVisitrDDList?serviceKey=o0CmhlAvqpjrYb4A%2BYeoTcpt5T9kN0rHF7L1Tcrw8Th1mDZaspp%2Bj0JaW9edrluemEotB58VFRjSoJKAqb88dQ%3D%3D&pageNo=1&numOfRows=20&MobileOS=ETC&MobileApp=AppTest&startYmd=20210501&endYmd=20210531&_type=json'
response = requests.get(url)

print(response.text)
# Out:
# {"response": {"header":{"resultCode":"0000","resultMsg":"OK"},"body": {"items": {"item":[{"areaCode":"11","areaNm":"서울특별시","daywkDivCd":"1","daywkDivNm":"월요일","touDivCd":"1","touDivNm":"현지인(a)","touNum":"4736837.0","baseYmd":"20210503"},{"areaCode":"11","areaNm":"서울특별시","daywkDivCd":"1","daywkDivNm":"월요일","touDivCd":"1","touDivNm":"현지인(a)","touNum":"4709267.5","baseYmd":"20210510"},{"areaCode":"11","areaNm":"서울특별시","daywkDivCd":"1","daywkDivNm":"월요일","touDivCd":"1","touDivNm":"현지인(a)","touNum":"4712281.0","baseYmd":"20210517"},{"areaCode":"11","areaNm":"서울특별시","daywkDivCd":"1","daywkDivNm":"월요일","touDivCd":"1","touDivNm":"현지인(a)","touNum":"4790905.0","baseYmd":"20210524"},{"areaCode":"11","areaNm":"서울특별시","daywkDivCd":"1","daywkDivNm":"월요일","touDivCd":"1","touDivNm":"현지인(a)","touNum":"4849743.5","baseYmd":"20210531"},{"areaCode":"11","areaNm":"서울특별시","daywkDivCd":"1","daywkDivNm":"월요일","touDivCd":"2","touDivNm":"외지인(b)","touNum":"1099931.0","baseYmd":"20210503"},{"areaCode":"11","are
# ...

# %%
json = response.json()
# print(json)
df = pd.DataFrame(json['response']['body']['items']['item'])
df
# Out:
#    areaCode areaNm daywkDivCd daywkDivNm touDivCd touDivNm             touNum  \
# 0        11  서울특별시          1        월요일        1   현지인(a)          4736837.0
# 1        11  서울특별시          1        월요일        1   현지인(a)          4709267.5
# 2        11  서울특별시          1        월요일        1   현지인(a)          4712281.0
# 3        11  서울특별시          1        월요일        1   현지인(a)          4790905.0
# 4        11  서울특별시          1        월요일        1   현지인(a)          4849743.5
# 5        11  서울특별시          1        월요일        2   외지인(b)          1099931.0
# 6        11  서울특별시          1        월요일        2   외지인(b)          1133079.5
# 7        11  서울특별시          1        월요일        2   외지인(b)          1216295.5
# 8        11  서울특별시          1        월요일        2   외지인(b)          1301349.0
# 9        11  서울특별시          1        월요일        2   외지인(b)          1340577.0
# 10       11  서울특별시          1        월요일        3   외국인(c)  2504.585199171259
# ...

# %%
# 한국관광공사_국문 관광정보 서비스

import json
import pandas as pd
import requests

service_key = "o0CmhlAvqpjrYb4A%2BYeoTcpt5T9kN0rHF7L1Tcrw8Th1mDZaspp%2Bj0JaW9edrluemEotB58VFRjSoJKAqb88dQ%3D%3D"
content_id = "Seoul"

url = f"http://apis.data.go.kr/B551011/KorService1/detailCommon1?serviceKey={service_key}&MobileOS=ETC&MobileApp=AppTest&contentId={content_id}&addrinfoYN=Y&_type=json&numOfRows=10"

response = requests.get(url)
print(response.text)
# Out:
# {"response": {"header":{"resultCode":"0000","resultMsg":"OK"},"body": {"items": "","numOfRows":0,"pageNo":1,"totalCount":0}}}

# %%
json = response.json()

df = pd.DataFrame(json['response'])
df
# Out:
#            header body
# resultCode   0000  NaN
# resultMsg      OK  NaN
# items         NaN
# numOfRows     NaN    0
# pageNo        NaN    1
# totalCount    NaN    0

# %%
# 한국관광공사_관광빅데이터 정보서비스_xml
import requests
import xml.etree.ElementTree as ET
import pandas as pd

url = 'http://apis.data.go.kr/B551011/DataLabService/metcoRegnVisitrDDList?serviceKey=o0CmhlAvqpjrYb4A%2BYeoTcpt5T9kN0rHF7L1Tcrw8Th1mDZaspp%2Bj0JaW9edrluemEotB58VFRjSoJKAqb88dQ%3D%3D&pageNo=1&numOfRows=20&MobileOS=ETC&MobileApp=AppTest&startYmd=20210501&endYmd=20210531&_type=xml'
response = requests.get(url)

print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header>
#   <resultCode>0000</resultCode>
#   <resultMsg>OK</resultMsg>
# </header><body><items>
#   <item>
#     <areaCode>11</areaCode>
#     <areaNm>서울특별시</areaNm>
#     <daywkDivCd>1</daywkDivCd>
#     <daywkDivNm>월요일</daywkDivNm>
#     <touDivCd>1</touDivCd>
#     <touDivNm>현지인(a)</touDivNm>
#     <touNum>4736837.0</touNum>
#     <baseYmd>20210503</baseYmd>
#   </item>
#   <item>
#     <areaCode>11</areaCode>
#     <areaNm>서울특별시</areaNm>
#     <daywkDivCd>1</daywkDivCd>
#     <daywkDivNm>월요일</daywkDivNm>
#     <touDivCd>1</touDivCd>
#     <touDivNm>현지인(a)</touDivNm>
#     <touNum>4709267.5</touNum>
#     <baseYmd>20210510</baseYmd>
#   </item>
#   <item>
#     <areaCode>11</areaCode>
#     <areaNm>서울특별시</areaNm>
#     <daywkDivCd>1</daywkDivCd>
#     <daywkDivNm>월요일</daywkDivNm>
#     <touDivCd>1</touDivCd>
#     <touDivNm>현지인(a)</touDivNm>
#     <touNum>4712281.0</touNum>
#     <baseYmd>20210517</baseYmd>
# ...

# %%
root = ET.fromstring(response.content)
data_list = []

for item in root.iter('item'):
    row = {}
    for i in item:
        row[i.tag] = child.text
    data_list.append(row)
    
df = pd.DataFrame(data_list)

print(df)
# Out:
#     areaCode    areaNm daywkDivCd daywkDivNm  touDivCd  touDivNm    touNum  \
# 0   20210504  20210504   20210504   20210504  20210504  20210504  20210504
# 1   20210504  20210504   20210504   20210504  20210504  20210504  20210504
# 2   20210504  20210504   20210504   20210504  20210504  20210504  20210504
# 3   20210504  20210504   20210504   20210504  20210504  20210504  20210504
# 4   20210504  20210504   20210504   20210504  20210504  20210504  20210504
# 5   20210504  20210504   20210504   20210504  20210504  20210504  20210504
# 6   20210504  20210504   20210504   20210504  20210504  20210504  20210504
# 7   20210504  20210504   20210504   20210504  20210504  20210504  20210504
# 8   20210504  20210504   20210504   20210504  20210504  20210504  20210504
# 9   20210504  20210504   20210504   20210504  20210504  20210504  20210504
# 10  20210504  20210504   20210504   20210504  20210504  20210504  20210504
# ...
